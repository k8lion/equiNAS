# %%
import utilities
from matplotlib.pyplot import imshow
# Out:
# /home/kaitlin/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:83: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
train_loader, validation_loader, test_loader = utilities.get_galaxy10_dataloaders(path_to_dir="..", batch_size=4, small=True)
# Out:
# False True
# making dataset
# <KeysViewHDF5 ['ans', 'dec', 'images', 'pxscale', 'ra', 'redshift']>
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
batch, labels = next(iter(train_loader))
#show images in batch with imshow
image = batch[0].numpy().transpose((1, 2, 0))
#renormalize each channel to [0,1]
for i in range(3):
    image[:,:,i] = (image[:,:,i] - image[:,:,i].min())/(image[:,:,i].max() - image[:,:,i].min())
print(image[:,:,0])
imshow(image)
# Out:
# [[0.18333471 0.1323545  0.12254655 ... 0.16666862 0.09607643 0.12254655]
#  [0.11372057 0.1294125  0.1617666  ... 0.11372057 0.20293887 0.10392044]
#  [0.23333295 0.1048985  0.05882031 ... 0.11470254 0.17745072 0.03627415]
#  ...
#  [0.1323545  0.1235246  0.16666862 ... 0.20097885 0.5401962  0.2647051 ]
#  [0.06372233 0.11372057 0.04215423 ... 0.11078248 0.25391906 0.0294082 ]
#  [0.07548638 0.07058437 0.09607643 ... 0.15392259 0.14607859 0.17745072]]
